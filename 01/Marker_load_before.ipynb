# %%
import pandas as pd
import numpy as np
from pandas import ExcelWriter
from openpyxl import Workbook
marker = pd.read_excel('After_Soc/1/Markers_1-2.xls')
marker = marker[np.isfinite(marker['sec'])]
marker
# Out:
#             [Main]                    Unnamed: 1            3  tic-tot  \
# 4    Position=1573                            ГЗ   [Marker 1]   1573.0
# 7    Position=3043                        ГЗ_end   [Marker 2]   3043.0
# 10   Position=5034   Extract per1 SetValue_Start   [Marker 3]   5034.0
# 13   Position=8249   Extract per3 SetValue_Start   [Marker 4]   8249.0
# 16   Position=9529   Extract per4 SetValue_Start   [Marker 5]   9529.0
# 19  Position=10357    Extract per4 ShowRes_Start   [Marker 6]  10357.0
# 22  Position=11560    Extract per5 ShowRes_Start   [Marker 7]  11560.0
# 25  Position=12600    Extract per6 ShowRes_Start   [Marker 8]  12600.0
# 28  Position=14026    Extract per7 ShowRes_Start   [Marker 9]  14026.0
# 31  Position=14527   Extract per8 SetValue_Start  [Marker 10]  14527.0
# 34  Position=15850   Extract per9 SetValue_Start  [Marker 11]  15850.0
# 37  Position=16679    Extract per9 ShowRes_Start  [Marker 12]  16679.0
# 40  Position=17205  Extract per10 SetValue_Start  [Marker 13]  17205.0
# 43  Position=18040                   Extract end  [Marker 14]  18040.0
# 46  Position=19026           Show res of Extract  [Marker 15]  19026.0
# 49  Position=20398   Contrib per1 SetValue_Start  [Marker 16]  20398.0
# 52  Position=24082   Contrib per3 SetValue_Start  [Marker 17]  24082.0
# 55  Position=34092   Contrib per8 SetValue_Start  [Marker 18]  34092.0
# 58  Position=36345   Contrib per9 SetValue_Start  [Marker 19]  36345.0
# 61  Position=37629    Contrib per9 ShowRes_Start  [Marker 20]  37629.0
# 64  Position=38942  Contrib per10 SetValue_Start  [Marker 21]  38942.0
# 67  Position=40642   Contrib per10 ShowRes_Start  [Marker 22]  40642.0
# 70  Position=42798                   Contrib end  [Marker 23]  42798.0
#
#     sec-tot   tic   min   sec         t  Δt, sec
# 4      31.0  23.0   0.0  31.0   0:31.23     31.0
# 7      60.0  43.0   1.0   0.0    1:0.43     29.0
# 10    100.0  34.0   1.0  40.0   1:40.34     40.0
# 13    164.0  49.0   2.0  44.0   2:44.49     64.0
# 16    190.0  29.0   3.0  10.0   3:10.29     26.0
# 19    207.0   7.0   3.0  27.0    3:27.7     17.0
# 22    231.0  10.0   3.0  51.0   3:51.10     24.0
# 25    252.0   0.0   4.0  12.0    4:12.0     21.0
# 28    280.0  26.0   4.0  40.0   4:40.26     28.0
# 31    290.0  27.0   4.0  50.0   4:50.27     10.0
# 34    317.0   0.0   5.0  17.0    5:17.0     27.0
# 37    333.0  29.0   5.0  33.0   5:33.29     16.0
# 40    344.0   5.0   5.0  44.0    5:44.5     11.0
# 43    360.0  40.0   6.0   0.0    6:0.40     16.0
# 46    380.0  26.0   6.0  20.0   6:20.26     20.0
# 49    407.0  48.0   6.0  47.0   6:47.48     27.0
# 52    481.0  32.0   8.0   1.0    8:1.32     74.0
# 55    681.0  42.0  11.0  21.0  11:21.42    200.0
# 58    726.0  45.0  12.0   6.0   12:6.45     45.0
# 61    752.0  29.0  12.0  32.0  12:32.29     26.0
# 64    778.0  42.0  12.0  58.0  12:58.42     26.0
# 67    812.0  42.0  13.0  32.0  13:32.42     34.0
# 70    855.0  48.0  14.0  15.0  14:15.48     43.0

# %%
start2
# Out:
# 3807.859

# %%
start_contrib
# Out:
# 41073.0

# %%
import pandas as pd
import numpy as np
from pandas import ExcelWriter
from openpyxl import Workbook

names = [u'Иванов Владислав',
u'Леонтьева Ксения',
u'Кравец Мария',
u'Тукина Юлия',
u'Дубенко Антон',
u'Акулов Дмитрий',
u'Гаврильчик Богдан',
u'Котова Маргарита',
u'Гуров Алексей',
u'Федотов Никита']

#folder = '2016-03-11_Collective_action'
state = 'Before_Soc'

wb = Workbook()
wb.save(filename = '{}_INFO.xlsx'.format(state))
for line in [1]:
    for n in range(10):
        if (n == 1): 
            from openpyxl import load_workbook

            book = load_workbook('{}_INFO.xlsx'.format(state))
            writer = pd.ExcelWriter('{}_INFO.xlsx'.format(state), engine='openpyxl') 
            writer.book = book
            writer.sheets = dict((ws.title, ws) for ws in book.worksheets)
            data = pd.DataFrame()
            data.to_excel(writer, sheet_name=str(n+1)+names[n])
            writer.save()
            
            
            continue
            
            
        if (2*n<9): x = pd.read_csv('{}/1/000{}_X'.format(state, 2*n), skiprows=10, sep=')', names = ['time','X'],index_col = False)
        if (2*n<9): y = pd.read_csv('{}/1/000{}_Y'.format(state, 2*n), skiprows=10, sep=')', names = ['time','Y'],index_col = False)
        if (2*n<9): z = pd.read_csv('{}/1/000{}_PZ'.format(state, 2*n+1), skiprows=10, sep=')',names = ['time','Z'],index_col = False)
        
        if (2*n>9): x = pd.read_csv('{}/2/000{}_X'.format(state, 2*(n-5)), skiprows=10, sep=')', names = ['time','X'],index_col = False)
        if (2*n>9): y = pd.read_csv('{}/2/000{}_Y'.format(state, 2*(n-5)), skiprows=10, sep=')', names = ['time','Y'],index_col = False)
        if (2*n>9): z = pd.read_csv('{}/2/000{}_PZ'.format(state, 2*(n-5)+1), skiprows=10, sep=')',names = ['time','Z'],index_col = False)
        
        #info = pd.read_excel('160401_SO1-2.xlsx',sheetname=u'160325_О1', index_col=0)
        #info2 = pd.read_excel('160325_SO1-2.xlsx',sheetname=u'О2', index_col=0)            
        data = x.merge(y).merge(z)
        #data['marker'] = '0'
        data['stad'] = '0'
        data['Profit'] = '0'
        data['TP'] = '0'
        data['LP'] = '0'
        data['Sum'] = '0'
        data['TH'] = '0'
        zt = pd.read_csv('160401_1437.csv',skiprows=32, sep = ';')
        a = list(zt.columns)
        a[0] = 'lol'
        zt.columns = a
        start = float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[1],[9]])[0][0])
        start2 = float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[1],[9]])[0][0])
        
        
        marker = pd.read_excel('Before_Soc/1/Markers_1-1.xls')
        marker = marker[np.isfinite(marker['sec'])]
        start_extract = float(np.array(marker.iloc[[2],[3]])[0][0])
        start_contrib = float(np.array(marker.iloc[[9],[3]])[0][0])
        
        data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start)))],[4]] = 'Extract per{} start'.format(1)

        data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[5]])[0][0])

        data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start)))],[7]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[30]])[0][0])

        data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[29]])[0][0])

        for u in range(2, 11):
            data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start)))],[4]] = 'Extract per{} start'.format(u)

            data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[5]])[0][0])

            data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start)))],[7]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[30]])[0][0])

            data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[29]])[0][0])


            if float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) == 0:
                data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 12 - start)))],[4]] = 'Extract per{} res'.format(u-1)
                data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 12 - start)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u-1)].iloc[[n],[5]])[0][0])
                data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 12 - start)))],[7]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u-1)].iloc[[n],[30]])[0][0])
                data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 12 - start)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u-1)].iloc[[n],[29]])[0][0])

            else:    
                data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start)))],[4]] = 'Extract per{} res'.format(u-1)
                data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u-1)].iloc[[n],[5]])[0][0])
                data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start)))],[7]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u-1)].iloc[[n],[30]])[0][0])
                data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u-1)].iloc[[n],[29]])[0][0])

                
        
        data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start2)))],[4]] = 'Contrib per{} start'.format(1)

        data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start2)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[5]])[0][0])

        data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start2)))],[6]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[50]])[0][0])

        data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start2)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[48]])[0][0])

        data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start2)))],[9]] = float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[29]])[0][0])

        data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start2)))],[9]] += float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[32]])[0][0])

        for u in range(2, 11):
            data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start2)))],[4]] = 'Contrib per{} start'.format(u)

            data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start2)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[5]])[0][0])

            data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start2)))],[6]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[50]])[0][0])

            data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start2)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[48]])[0][0])

            data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start2)))],[9]] = float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[29]])[0][0])

            data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start2)))],[9]] += float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[32]])[0][0])



            if float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) == 0:
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 20 - start2)))],[4]] = 'Contrib per{} res'.format(u-1)
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 20 - start2)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[5]])[0][0])
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 20 - start2)))],[6]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[50]])[0][0])
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 20 - start2)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[48]])[0][0])
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 20 - start2)))],[9]] = float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[29]])[0][0])
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 20 - start2)))],[9]] += float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[32]])[0][0])

            else:    
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start2)))],[4]] = 'Contrib per{} res'.format(u-1)
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start2)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[5]])[0][0])
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start2)))],[6]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[50]])[0][0])
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start2)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[48]])[0][0])
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start2)))],[9]] = float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[29]])[0][0])
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start2)))],[9]] += float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[32]])[0][0])

        data.iloc[[j for j in range (0,np.array(marker['tic-tot'].astype(int))[0])],[4]] = u'ГО'
        data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[0],np.array(marker['tic-tot'].astype(int))[1])],[4]] = u'ГЗ'
        
        data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[20],np.array(marker['tic-tot'].astype(int))[21])],[4]] = u'ГО'
        data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[21],np.array(marker['tic-tot'].astype(int))[22])],[4]] = u'ГЗ'


        
        from openpyxl import load_workbook

        book = load_workbook('{}_INFO.xlsx'.format(state))
        writer = pd.ExcelWriter('{}_INFO.xlsx'.format(state), engine='openpyxl') 
        writer.book = book
        writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

        data.to_excel(writer, sheet_name=str(n+1)+names[n])
        
        writer.save()
# Out:
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:61: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:62: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:70: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:72: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:74: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:76: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:79: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:81: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:83: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:85: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:88: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:95: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:96: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:97: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:98: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:102: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:104: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:106: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:108: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:110: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:112: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:115: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:117: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:119: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:121: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:123: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:125: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:129: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:130: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:131: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:132: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:133: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:134: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:135: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:138: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:139: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:140: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:141: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:142: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:143: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:89: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:90: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:91: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:92: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
n
# Out:
# 1

# %%
u
# Out:
# 9

# %%
data
# Out:
#            time          X          Y          Z stad Profit TP LP Sum TH
# 0       00:00.0  19.507812 -76.000000 -48.279266    0      0  0  0   0  0
# 1       00:00.2  19.562500 -75.984375 -48.296844    0      0  0  0   0  0
# 2       00:00.4  19.601562 -76.015625 -48.274841    0      0  0  0   0  0
# 3       00:00.6  19.671875 -76.085938 -48.226074    0      0  0  0   0  0
# 4       00:00.8  19.750000 -76.156250 -48.191528    0      0  0  0   0  0
# 5      00:00.10  19.804688 -76.203125 -48.183228    0      0  0  0   0  0
# 6      00:00.12  19.812500 -76.203125 -48.197052    0      0  0  0   0  0
# 7      00:00.14  19.796875 -76.179688 -48.210144    0      0  0  0   0  0
# 8      00:00.16  19.773438 -76.171875 -48.196228    0      0  0  0   0  0
# 9      00:00.18  19.734375 -76.125000 -48.181915    0      0  0  0   0  0
# 10     00:00.20  19.695312 -76.093750 -48.177032    0      0  0  0   0  0
# 11     00:00.22  19.648438 -76.101562 -48.172180    0      0  0  0   0  0
# 12     00:00.24  19.578125 -76.164062 -48.164093    0      0  0  0   0  0
# 13     00:00.26  19.500000 -76.203125 -48.168793    0      0  0  0   0  0
# 14     00:00.28  19.429688 -76.242188 -48.177826    0      0  0  0   0  0
# 15     00:00.30  19.382812 -76.257812 -48.190369    0      0  0  0   0  0
# 16     00:00.32  19.390625 -76.242188 -48.216644    0      0  0  0   0  0
# 17     00:00.34  19.453125 -76.281250 -48.225098    0      0  0  0   0  0
# 18     00:00.36  19.531250 -76.343750 -48.211365    0      0  0  0   0  0
# 19     00:00.38  19.617188 -76.437500 -48.172119    0      0  0  0   0  0
# 20     00:00.40  19.671875 -76.484375 -48.141724    0      0  0  0   0  0
# 21     00:00.42  19.718750 -76.515625 -48.115204    0      0  0  0   0  0
# 22     00:00.44  19.750000 -76.515625 -48.111084    0      0  0  0   0  0
# 23     00:00.46  19.742188 -76.539062 -48.120422    0      0  0  0   0  0
# 24     00:00.48  19.671875 -76.570312 -48.134216    0      0  0  0   0  0
# 25     00:00.50  19.570312 -76.585938 -48.162262    0      0  0  0   0  0
# 26     00:00.52  19.468750 -76.656250 -48.163940    0      0  0  0   0  0
# 27     00:00.54  19.375000 -76.750000 -48.156616    0      0  0  0   0  0
# 28     00:00.56  19.289062 -76.789062 -48.153076    0      0  0  0   0  0
# 29     00:00.58  19.226562 -76.835938 -48.158264    0      0  0  0   0  0
# ...         ...        ...        ...        ...  ...    ... .. ..  .. ..
# 58522  19:30.44   0.000000   0.000000   0.026093    0      0  0  0   0  0
# 58523  19:30.46   0.000000   0.000000   0.034760    0      0  0  0   0  0
# 58524  19:30.48   0.000000   0.000000   0.029938    0      0  0  0   0  0
# 58525  19:30.50   0.000000   0.000000   0.030121    0      0  0  0   0  0
# 58526  19:30.52   0.000000   0.000000   0.030182    0      0  0  0   0  0
# 58527  19:30.54   0.000000   0.000000   0.030121    0      0  0  0   0  0
# 58528  19:30.56   0.000000   0.000000   0.025970    0      0  0  0   0  0
# 58529  19:30.58   0.000000   0.000000   0.026031    0      0  0  0   0  0
# 58530  19:30.60   0.000000   0.000000   0.026093    0      0  0  0   0  0
# 58531  19:30.62   0.000000   0.000000   0.030121    0      0  0  0   0  0
# 58532  19:30.64   0.000000   0.000000   0.030182    0      0  0  0   0  0
# 58533  19:30.66   0.000000   0.000000   0.029999    0      0  0  0   0  0
# 58534  19:30.68   0.000000   0.000000   0.026093    0      0  0  0   0  0
# 58535  19:30.70   0.000000   0.000000   0.030670    0      0  0  0   0  0
# 58536  19:30.72   0.000000   0.000000   0.030670    0      0  0  0   0  0
# 58537  19:30.74   0.000000   0.000000   0.026093    0      0  0  0   0  0
# 58538  19:30.76   0.000000   0.000000   0.030151    0      0  0  0   0  0
# 58539  19:30.78   0.000000   0.000000   0.026093    0      0  0  0   0  0
# 58540  19:30.80   0.000000   0.000000   0.034943    0      0  0  0   0  0
# 58541  19:30.82   0.000000   0.000000   0.030670    0      0  0  0   0  0
# 58542  19:30.84   0.000000   0.000000   0.026093    0      0  0  0   0  0
# 58543  19:30.86   0.000000   0.000000   0.026093    0      0  0  0   0  0
# 58544  19:30.88   0.000000   0.000000   0.034912    0      0  0  0   0  0
# 58545  19:30.90   0.000000   0.000000   0.026184    0      0  0  0   0  0
# 58546  19:30.92   0.000000   0.000000   0.026093    0      0  0  0   0  0
# 58547  19:30.94   0.000000   0.000000   0.030365    0      0  0  0   0  0
# 58548  19:30.96   0.000000   0.000000   0.030182    0      0  0  0   0  0
# 58549  19:30.98   0.000000   0.000000   0.025970    0      0  0  0   0  0
# 58550   19:31.0   0.000000   0.000000   0.030182    0      0  0  0   0  0
# 58551   19:31.2   0.000000   0.000000   0.026031    0      0  0  0   0  0
#
# [58552 rows x 10 columns]

# %%
import pandas as pd
import numpy as np
from pandas import ExcelWriter
from openpyxl import Workbook

names = [u'Гуров Алексей',
u'Калмыкова Светлана',
u'Акулов Дмитрий',
u'Гаврильчик Богдан',
u'Котова Маргарита',
u'Прокопов Иван',
u'Дубенко Антон',
u'Тукина Юлия',
u'Федотов Никита',
u'Кравец Мария']

#folder = '2016-03-11_Collective_action'
state = 'After_Soc'



wb = Workbook()
wb.save(filename = '{}_INFO.xlsx'.format(state))
for line in [1]:
    for n in range(10):
        
            
            
        if (2*n<9): x = pd.read_csv('{}/1/000{}_X'.format(state, 2*n), skiprows=10, sep=')', names = ['time','X'],index_col = False)
        if (2*n<9): y = pd.read_csv('{}/1/000{}_Y'.format(state, 2*n), skiprows=10, sep=')', names = ['time','Y'],index_col = False)
        if (2*n<9): z = pd.read_csv('{}/1/000{}_PZ'.format(state, 2*n+1), skiprows=10, sep=')',names = ['time','Z'],index_col = False)
        
        if (2*n>9): x = pd.read_csv('{}/2/000{}_X'.format(state, 2*(n-5)), skiprows=10, sep=')', names = ['time','X'],index_col = False)
        if (2*n>9): y = pd.read_csv('{}/2/000{}_Y'.format(state, 2*(n-5)), skiprows=10, sep=')', names = ['time','Y'],index_col = False)
        if (2*n>9): z = pd.read_csv('{}/2/000{}_PZ'.format(state, 2*(n-5)+1), skiprows=10, sep=')',names = ['time','Z'],index_col = False)

        #info = pd.read_excel('160325_SO1-2.xlsx',sheetname=u'160325_Г1', index_col=0)
        #info2 = pd.read_excel('160325_SO1-2.xlsx',sheetname=u'Г2', index_col=0)            
        data = x.merge(y).merge(z)
        #data['marker'] = '0'
        data['stad'] = '0'
        data['Profit'] = '0'
        data['TP'] = '0'
        data['LP'] = '0'
        data['Sum'] = '0'
        data['TH'] = '0'
        zt = pd.read_csv('160401_1555.csv',skiprows=32, sep = ';')
        a = list(zt.columns)
        a[0] = 'lol'
        zt.columns = a
        start = float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[1],[9]])[0][0])
        start2 = float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[1],[9]])[0][0])
        
        
        marker = pd.read_excel('After_Soc/1/Markers_1-2.xls')
        marker = marker[np.isfinite(marker['sec'])]
        start_extract = float(np.array(marker.iloc[[2],[3]])[0][0])
        start_contrib = float(np.array(marker.iloc[[15],[3]])[0][0])
        
        data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start)))],[4]] = 'Extract per{} start'.format(1)

        data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[5]])[0][0])

        data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start)))],[7]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[30]])[0][0])

        data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[29]])[0][0])

        for u in range(2, 11):
            data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start)))],[4]] = 'Extract per{} start'.format(u)

            data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[5]])[0][0])

            data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start)))],[7]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[30]])[0][0])

            data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[29]])[0][0])


            if float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) == 0:
                data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 5 - start)))],[4]] = 'Extract per{} res'.format(u-1)
                data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 5 - start)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u-1)].iloc[[n],[5]])[0][0])
                data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 5 - start)))],[7]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u-1)].iloc[[n],[30]])[0][0])
                data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 5 - start)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u-1)].iloc[[n],[29]])[0][0])

            else:    
                data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start)))],[4]] = 'Extract per{} res'.format(u-1)
                data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u-1)].iloc[[n],[5]])[0][0])
                data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start)))],[7]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u-1)].iloc[[n],[30]])[0][0])
                data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u-1)].iloc[[n],[29]])[0][0])

                
        
        data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start2)))],[4]] = 'Contrib per{} start'.format(1)

        data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start2)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[5]])[0][0])

        data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start2)))],[6]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[50]])[0][0])

        data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start2)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[48]])[0][0])

        data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start2)))],[9]] = float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[29]])[0][0])

        data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start2)))],[9]] += float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[32]])[0][0])

        for u in range(2, 11):
            data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start2)))],[4]] = 'Contrib per{} start'.format(u)

            data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start2)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[5]])[0][0])

            data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start2)))],[6]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[50]])[0][0])

            data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start2)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[48]])[0][0])

            data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start2)))],[9]] = float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[29]])[0][0])

            data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start2)))],[9]] += float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[32]])[0][0])



            if float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) == 0:
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 20 - start2)))],[4]] = 'Contrib per{} res'.format(u-1)
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 20 - start2)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[5]])[0][0])
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 20 - start2)))],[6]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[50]])[0][0])
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 20 - start2)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[48]])[0][0])
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 20 - start2)))],[9]] = float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[29]])[0][0])
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 20 - start2)))],[9]] += float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[32]])[0][0])

            else:    
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start2)))],[4]] = 'Contrib per{} res'.format(u-1)
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start2)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[5]])[0][0])
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start2)))],[6]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[50]])[0][0])
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start2)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[48]])[0][0])
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start2)))],[9]] = float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[29]])[0][0])
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start2)))],[9]] += float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[32]])[0][0])

        data.iloc[[j for j in range (0,np.array(marker['tic-tot'].astype(int))[0])],[4]] = u'ГО'
        data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[0],np.array(marker['tic-tot'].astype(int))[1])],[4]] = u'ГЗ'
        
        #data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[7],np.array(marker['tic-tot'].astype(int))[8])],[4]] = u'ГО'
        #data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[8],np.array(marker['tic-tot'].astype(int))[9])],[4]] = u'ГЗ'
        
        from openpyxl import load_workbook

        book = load_workbook('{}_INFO.xlsx'.format(state))
        writer = pd.ExcelWriter('{}_INFO.xlsx'.format(state), engine='openpyxl') 
        writer.book = book
        writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

        data.to_excel(writer, sheet_name=str(n+1)+names[n])
        
        writer.save()
# Out:
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:51: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:52: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:60: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:62: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:64: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:66: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:69: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:71: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:73: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:75: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:78: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:85: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:86: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:87: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:88: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:92: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:94: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:96: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:98: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:100: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:102: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:105: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:107: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:109: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:111: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:113: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:115: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:119: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:128: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:129: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:130: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:131: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:132: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:133: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:120: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:121: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:122: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:123: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:124: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:125: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:79: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:80: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:81: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:82: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
line = 1
n = 0
u = 3 
np.array(info2.iloc[[12*(int((u+1)/2.)-11)+5*(line-1)+n],[8]])[0][0]

# %%
marker

# %%
data

# %%
        line = 1
        n = 0
        x = pd.read_csv('{}/{}/000{}_X'.format(state,line,2*n), skiprows=10, sep=')', names = ['time','X'],index_col = False)
        y = pd.read_csv('{}/{}/000{}_Y'.format(state,line,2*n), skiprows=10, sep=')', names = ['time','Y'],index_col = False)
        z = pd.read_csv('{}/{}/000{}_PZ'.format(state,line,2*n+1), skiprows=10, sep=')',names = ['time','Z'],index_col = False)
        info = pd.read_excel('160318_SO1-2.xlsx',sheetname=u'160318_О1', index_col=0)
        info2 = pd.read_excel('160318_SO1-2.xlsx',sheetname=u'О2', index_col=0)
        data = x.merge(y).merge(z)
        data['marker'] = '0'
        data['stad'] = '0'

        marker = pd.read_excel('Before_Soc/1/Markers_1-1.xls')
        marker = marker[np.isfinite(marker['sec'])]

        for u in range(len(marker['tic-tot'])-1):
            data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[4]] = 'Marker {}'.format(u+1)
    
        for u in range(2,21,2):
            data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[5]] = 'Extract per{} start'.format(int((u-1)/2.)+1)

        for u in range(3,21,2):
            data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[5]] = 'Extract per{} res'.format(int((u-1)/2.))
    
        for u in range(21,41,2):
            data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[5]] = 'Contrib per{} start'.format(int((u-1)/2.)-9)
    
        for u in range(22,41,2):
            data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[5]] = 'Contrib per{} res'.format(int((u-1)/2.)-9)
        
        data.iloc[[j for j in range (0,np.array(marker['tic-tot'].astype(int))[0])],[4]] = 'Marker 0'
        data.iloc[[j for j in range (0,np.array(marker['tic-tot'].astype(int))[0])],[5]] = u'ГО'
        data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[0],np.array(marker['tic-tot'].astype(int))[1])],[5]] = u'ГЗ'

        data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[41],np.array(marker['tic-tot'].astype(int))[42])],[5]] = 'Contrib end'
        data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[42],np.array(marker['tic-tot'].astype(int))[43])],[5]] = 'ГО'

        data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[43],np.array(marker['tic-tot'].astype(int))[44])],[5]] = 'ГЗ'



        data['Profit'] = '0'
        data['TP'] = '0'
        data['LP'] = '0'
        data['Sum'] = '0'
        data['TH'] = '0'
        
        for u in range(2,21):
            data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[6]] = np.array(info.iloc[[12*(int((u)/2.)-1)+5*(line-1)+n],[2]])[0][0]
            data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[8]] = np.array(info.iloc[[12*(int((u)/2.)-1)+5*(line-1)+n],[6]])[0][0]
            data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[9]] = np.array(info.iloc[[12*(int((u)/2.)-1)+5*(line-1)+n],[5]])[0][0]
            
        for u in range(21,41):
            data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[6]] = np.array(info2.iloc[[12*(int((u+1)/2.)-11)+5*(line-1)+n],[2]])[0][0]
            data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[7]] = np.array(info2.iloc[[12*(int((u+1)/2.)-11)+5*(line-1)+n],[15]])[0][0]
            data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[9]] = np.array(info2.iloc[[12*(int((u+1)/2.)-11)+5*(line-1)+n],[13]])[0][0]
          
            if line == 1: data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[10]] = np.array(info2.iloc[[12*(int((u+1)/2.)-11)+5*(line-1)+n],[8]])[0][0]
            if line == 2: data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[10]] = np.array(info2.iloc[[12*(int((u+1)/2.)-11)+5*(line-1)+n],[11]])[0][0]

# %%
data[35000:35010]

# %%
data.to_excel("loltest.xlsx")

# %%
lol = pd.read_excel("After_Soc_INFO.xlsx", sheetname=u'1Преображенский Артём')

# %%
lol[lol.stad == 'Contrib per1 start'].index

# %%
df = lol.drop(lol[lol.stad == '0'].index)

# %%
lol1 = df.groupby('stad')

# %%
lol1.groups.keys()

# %%
lol1.groups

# %%
 c = [lol1.get_group(x) for x in lol1.groups]

# %%
c

# %%
markers = [max(j.index) for j in c]

# %%
markers.append(int(np.array(marker['tic-tot'].iloc[[0]])[0]))
markers.append(int(np.array(marker['tic-tot'].iloc[[1]])[0]))

# %%
np.sort(markers)

# %%
        n = 2
        if (2*n<9): x = pd.read_csv('{}/1/000{}_X'.format(state, 2*n), skiprows=10, sep=')', names = ['time','X'],index_col = False)
        if (2*n<9): y = pd.read_csv('{}/1/000{}_Y'.format(state, 2*n), skiprows=10, sep=')', names = ['time','Y'],index_col = False)
        if (2*n<9): z = pd.read_csv('{}/1/000{}_PZ'.format(state, 2*n+1), skiprows=10, sep=')',names = ['time','Z'],index_col = False)
        
        if (2*n>9): x = pd.read_csv('{}/2/000{}_X'.format(state, 2*(n-5)), skiprows=10, sep=')', names = ['time','X'],index_col = False)
        if (2*n>9): y = pd.read_csv('{}/2/000{}_Y'.format(state, 2*(n-5)), skiprows=10, sep=')', names = ['time','Y'],index_col = False)
        if (2*n>9): z = pd.read_csv('{}/2/000{}_PZ'.format(state, 2*(n-5)+1), skiprows=10, sep=')',names = ['time','Z'],index_col = False)

        info = pd.read_excel('160325_SO1-2.xlsx',sheetname=u'160325_Г1', index_col=0)
        info2 = pd.read_excel('160325_SO1-2.xlsx',sheetname=u'Г2', index_col=0)            
        data = x.merge(y).merge(z)
        #data['marker'] = '0'
        data['stad'] = '0'
        data['Profit'] = '0'
        data['TP'] = '0'
        data['LP'] = '0'
        data['Sum'] = '0'
        data['TH'] = '0'
        zt = pd.read_csv('160325_1347.csv',skiprows=32, sep = ';')
        a = list(zt.columns)
        a[0] = 'lol'
        zt.columns = a
        start = float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[1],[9]])[0][0])
        start2 = float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[1],[9]])[0][0])
        
        
        marker = pd.read_excel('After_Soc/1/Markers_1-2.xls')
        marker = marker[np.isfinite(marker['sec'])]
        start_extract = float(np.array(marker.iloc[[2],[3]])[0][0])
        start_contrib = float(np.array(marker.iloc[[5],[3]])[0][0])
        
        data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start)))],[4]] = 'Extract per{} start'.format(1)

        data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[5]])[0][0])

        data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start)))],[7]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[30]])[0][0])

        data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[n],[29]])[0][0])

        for u in range(2, 11):
            data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start)))],[4]] = 'Extract per{} start'.format(u)

            data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[5]])[0][0])

            data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start)))],[7]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[30]])[0][0])

            data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[29]])[0][0])


            if float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[u],[12]])[0][0]) == 0:
                data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 5 - start)))],[4]] = 'Extract per{} res'.format(u-1)
                data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 5 - start)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u-1)].iloc[[n],[5]])[0][0])
                data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 5 - start)))],[7]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u-1)].iloc[[n],[30]])[0][0])
                data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 5 - start)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u-1)].iloc[[n],[29]])[0][0])

            else:    
                data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start)))],[4]] = 'Extract per{} res'.format(u-1)
                data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u-1)].iloc[[n],[5]])[0][0])
                data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start)))],[7]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u-1)].iloc[[n],[30]])[0][0])
                data.iloc[[j for j in range (int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u-1)].iloc[[n],[29]])[0][0])

                
        
        data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start2)))],[4]] = 'Contrib per{} start'.format(1)

        data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start2)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[5]])[0][0])

        data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start2)))],[6]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[50]])[0][0])

        data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start2)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[48]])[0][0])

        data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start2)))],[9]] = float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[29]])[0][0])

        data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start2)))],[9]] += float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[32]])[0][0])

        for u in range(2, 11):
            data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start2)))],[4]] = 'Contrib per{} start'.format(u)

            data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start2)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[5]])[0][0])

            data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start2)))],[6]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[50]])[0][0])

            data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start2)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[48]])[0][0])

            data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start2)))],[9]] = float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[29]])[0][0])

            data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start2)))],[9]] += float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[32]])[0][0])



            if float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) == 0:
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 20 - start2)))],[4]] = 'Contrib per{} res'.format(u-1)
                if u == 10: print int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2))
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 20 - start2)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[5]])[0][0])
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 20 - start2)))],[6]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[50]])[0][0])
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 20 - start2)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[48]])[0][0])
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 20 - start2)))],[9]] = float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[29]])[0][0])
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 20 - start2)))],[9]] += float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[32]])[0][0])

            else:    
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start2)))],[4]] = 'Contrib per{} res'.format(u-1)
                if u == 10: print int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0])
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start2)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[5]])[0][0])
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start2)))],[6]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[50]])[0][0])
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start2)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[48]])[0][0])
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start2)))],[9]] = float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[29]])[0][0])
                data.iloc[[j for j in range (int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start2)))],[9]] += float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[32]])[0][0])

        data.iloc[[j for j in range (0,np.array(marker['tic-tot'].astype(int))[0])],[4]] = u'ГО'
        data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[0],np.array(marker['tic-tot'].astype(int))[1])],[4]] = u'ГЗ'
        
        data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[7],np.array(marker['tic-tot'].astype(int))[8])],[4]] = u'ГО'
        data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[8],np.array(marker['tic-tot'].astype(int))[9])],[4]] = u'ГЗ'

# %%
data = data.drop(data[data.stad == '0'].index)
        
data = data.reset_index()
marker = pd.read_excel('After_Soc/1/Markers_1-2.xls')
marker = marker[np.isfinite(marker['sec'])]
        
lol12 = data.groupby('stad')

# %%
np.sort(lol12.groups.keys())

# %%
np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(8)].iloc[[8],[12]])[0][0]
