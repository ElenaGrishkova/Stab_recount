# %%
import pandas as pd
import numpy as np
from pandas import ExcelWriter
from openpyxl import Workbook

names1 = [u'Николаева Анна',
u'Мухаметдинов Гаяз',
u'Магнитов Михаил',
u'Пономарев Евгений',
u'Ишханян Аршак']
names2 = [
u'Исрафилов Ильдар',
u'Рулев Георгий',
u'Биктайров Роман',
u'Шилов Иннокентий',
u'Лескин Иван']
#folder = '2016-03-11_Collective_action'
state = 'After_Soc'
label = 2


wb = Workbook()
wb.save(filename = '{}_INFO.xlsx'.format(state))
for line in [1,2]:
    for n in range(5):
        if (line == 1) and (n == 4): 
            from openpyxl import load_workbook

            book = load_workbook('{}_INFO.xlsx'.format(state))
            writer = pd.ExcelWriter('{}_INFO.xlsx'.format(state), engine='openpyxl') 
            writer.book = book
            writer.sheets = dict((ws.title, ws) for ws in book.worksheets)
            data = pd.DataFrame()
            if (line == 1) : 
                data.to_excel(writer, sheet_name=str(n+5*(line-1)+1)+names1[n])
            else :
                data.to_excel(writer, sheet_name=str(n+5*(line-1)+1)+names2[n])
            writer.save()
            
            
            continue
        if line ==1 : x = pd.read_csv('{}/{}/000{}_X'.format(state,line,3*n), skiprows=10, sep=')', names = ['time','X'],index_col = False)
        else: x = pd.read_csv('{}/{}/000{}_X'.format(state,line,2*n), skiprows=10, sep=')', names = ['time','X'],index_col = False)

        if line == 1: y = pd.read_csv('{}/{}/000{}_Y'.format(state,line,3*n), skiprows=10, sep=')', names = ['time','Y'],index_col = False)
        else: y = pd.read_csv('{}/{}/000{}_Y'.format(state,line,2*n), skiprows=10, sep=')', names = ['time','Y'],index_col = False)
        if line == 1: z = pd.read_csv('{}/{}/000{}_Z'.format(state,line,3*n+1), skiprows=10, sep=')',names = ['time','Z'],index_col = False)
        if line == 2: z = pd.read_csv('{}/{}/000{}_PZ'.format(state,line,2*n+1), skiprows=10, sep=')',names = ['time','Z'],index_col = False)
        info = pd.read_excel('160318_SO1-2.xlsx',sheetname=u'160318_Г1', index_col=0)
        info2 = pd.read_excel('160318_SO1-2.xlsx',sheetname=u'Г2', index_col=0)
        data = x.merge(y).merge(z)
        data['marker'] = '0'
        data['stad'] = '0'

        marker = pd.read_excel('{}/1/Markers_1-{}.xls'.format(state,label))
        marker = marker[np.isfinite(marker['sec'])]

        for u in range(len(marker['tic-tot'])-1):
            data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[4]] = 'Marker {}'.format(u+1)
    
        for u in range(2,22,2):
            data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[5]] = 'Extract per{} start'.format(int((u-1)/2.)+1)

        for u in range(3,22,2):
            data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[5]] = 'Extract per{} res'.format(int((u-1)/2.))
    
        for u in range(22,42,2):
            data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[5]] = 'Contrib per{} start'.format(int((u-1)/2.)-9)
    
        for u in range(23,42,2):
            data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[5]] = 'Contrib per{} res'.format(int((u-1)/2.)-9)
        
        data.iloc[[j for j in range (0,np.array(marker['tic-tot'].astype(int))[0])],[4]] = 'Marker 0'
        data.iloc[[j for j in range (0,np.array(marker['tic-tot'].astype(int))[0])],[5]] = u'ГО'
        data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[0],np.array(marker['tic-tot'].astype(int))[1])],[5]] = u'ГЗ'

        #data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[42],np.array(marker['tic-tot'].astype(int))[43])],[5]] = 'Contrib end'


        data['Profit'] = '0'
        data['TP'] = '0'
        data['LP'] = '0'
        data['Sum'] = '0'
        data['TH'] = '0'
        
        for u in range(2,22):
            data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[6]] = np.array(info.iloc[[12*(int((u)/2.)-1)+5*(line-1)+n],[2]])[0][0]
            data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[8]] = np.array(info.iloc[[12*(int((u)/2.)-1)+5*(line-1)+n],[6]])[0][0]
            data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[9]] = np.array(info.iloc[[12*(int((u)/2.)-1)+5*(line-1)+n],[5]])[0][0]
            
        for u in range(22,42):
            data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[6]] = np.array(info2.iloc[[12*(int((u+1)/2.)-11)+5*(line-1)+n],[2]])[0][0]
            data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[7]] = np.array(info2.iloc[[12*(int((u+1)/2.)-11)+5*(line-1)+n],[15]])[0][0]
            data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[9]] = np.array(info2.iloc[[12*(int((u+1)/2.)-11)+5*(line-1)+n],[13]])[0][0]
          
            if line == 1: data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[10]] = np.array(info2.iloc[[12*(int((u+1)/2.)-11)+5*(line-1)+n],[8]])[0][0]
            if line == 2: data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[10]] = np.array(info2.iloc[[12*(int((u+1)/2.)-11)+5*(line-1)+n],[11]])[0][0]
        

        
        
        from openpyxl import load_workbook

        book = load_workbook('{}_INFO.xlsx'.format(state))
        writer = pd.ExcelWriter('{}_INFO.xlsx'.format(state), engine='openpyxl') 
        writer.book = book
        writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

        if (line == 1) : 
            data.to_excel(writer, sheet_name=str(n+5*(line-1)+1)+names1[n])
        else :
            data.to_excel(writer, sheet_name=str(n+5*(line-1)+1)+names2[n])
        writer.save()

# %%
x
# Out:
#            time         X
# 0       00:00.0 -3.390625
# 1       00:00.2 -3.781250
# 2       00:00.4 -4.218750
# 3       00:00.6 -4.671875
# 4       00:00.8 -5.093750
# 5      00:00.10 -5.492188
# 6      00:00.12 -5.890625
# 7      00:00.14 -6.257812
# 8      00:00.16 -6.570312
# 9      00:00.18 -6.812500
# 10     00:00.20 -6.968750
# 11     00:00.22 -7.062500
# 12     00:00.24 -7.132812
# 13     00:00.26 -7.125000
# 14     00:00.28 -7.070312
# 15     00:00.30 -6.968750
# 16     00:00.32 -6.859375
# 17     00:00.34 -6.718750
# 18     00:00.36 -6.585938
# 19     00:00.38 -6.445312
# 20     00:00.40 -6.312500
# 21     00:00.42 -6.179688
# 22     00:00.44 -6.054688
# 23     00:00.46 -5.945312
# 24     00:00.48 -5.843750
# 25     00:00.50 -5.757812
# 26     00:00.52 -5.726562
# 27     00:00.54 -5.757812
# 28     00:00.56 -5.812500
# 29     00:00.58 -5.875000
# ...         ...       ...
# 27768  09:15.36 -2.203125
# 27769  09:15.38 -2.398438
# 27770  09:15.40 -2.539062
# 27771  09:15.42 -2.687500
# 27772  09:15.44 -2.820312
# 27773  09:15.46 -2.859375
# 27774  09:15.48 -2.750000
# 27775  09:15.50 -2.492188
# 27776  09:15.52 -2.062500
# 27777  09:15.54 -1.484375
# 27778  09:15.56 -0.804688
# 27779  09:15.58 -0.078125
# 27780  09:15.60  0.640625
# 27781  09:15.62  1.304688
# 27782  09:15.64  1.929688
# 27783  09:15.66  2.398438
# 27784  09:15.68  2.546875
# 27785  09:15.70  2.312500
# 27786  09:15.72  1.742188
# 27787  09:15.74  0.968750
# 27788  09:15.76  0.085938
# 27789  09:15.78 -0.781250
# 27790  09:15.80 -1.632812
# 27791  09:15.82 -2.492188
# 27792  09:15.84 -3.320312
# 27793  09:15.86 -4.007812
# 27794  09:15.88 -4.484375
# 27795  09:15.90 -4.789062
# 27796  09:15.92 -4.828125
# 27797  09:15.94 -4.500000
#
# [27798 rows x 2 columns]

# %%
import pandas as pd
import numpy as np
state = 'After_Soc'
line = 1
n = 0
x = pd.read_csv('{}/{}/000{}_X'.format(state,line,2*n), skiprows=10, sep=')', names = ['time','X'],index_col = False)
y = pd.read_csv('{}/{}/000{}_Y'.format(state,line,2*n), skiprows=10, sep=')', names = ['time','Y'],index_col = False)
z = pd.read_csv('{}/{}/000{}_Z'.format(state,line,2*n+1), skiprows=10, sep=')',names = ['time','Z'],index_col = False)
info = pd.read_excel('160318_SO1-2.xlsx',sheetname=u'160318_О1', index_col=0)
info2 = pd.read_excel('160318_SO1-2.xlsx',sheetname=u'О2', index_col=0)
data = x.merge(y).merge(z)
data['marker'] = '0'
data['stad'] = '0'

marker = pd.read_excel('{}/1/Markers_1-2.xls'.format(state))
marker = marker[np.isfinite(marker['sec'])]

for u in range(len(marker['tic-tot'])-1):
     data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[4]] = 'Marker {}'.format(u+1)
    
for u in range(2,21,2):
     data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[5]] = 'Extract per{} start'.format(int((u-1)/2.)+1)

for u in range(3,21,2):
     data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[5]] = 'Extract per{} res'.format(int((u-1)/2.))
    
for u in range(21,41,2):
     data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[5]] = 'Contrib per{} start'.format(int((u-1)/2.)-9)
    
for u in range(21,41,2):
     data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[5]] = 'Contrib per{} res'.format(int((u-1)/2.)-9)
        
data.iloc[[j for j in range (0,np.array(marker['tic-tot'].astype(int))[0])],[4]] = 'Marker 0'
data.iloc[[j for j in range (0,np.array(marker['tic-tot'].astype(int))[0])],[5]] = u'ГО'
data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[0],np.array(marker['tic-tot'].astype(int))[1])],[5]] = u'ГЗ'

data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[41],np.array(marker['tic-tot'].astype(int))[42])],[5]] = 'Contrib end'
        
data['Profit'] = '0'
data['TP'] = '0'
data['LP'] = '0'
data['Sum'] = '0'
data['TH'] = '0'
        
for u in range(2,21):
    data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[6]] = np.array(info.iloc[[12*(int((u)/2.)-1)+5*(line-1)+n],[2]])[0][0]
    data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[8]] = np.array(info.iloc[[12*(int((u)/2.)-1)+5*(line-1)+n],[6]])[0][0]
    data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[9]] = np.array(info.iloc[[12*(int((u)/2.)-1)+5*(line-1)+n],[5]])[0][0]
            
for u in range(21,41):
    data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[6]] = np.array(info2.iloc[[12*(int((u+1)/2.)-11)+5*(line-1)+n],[2]])[0][0]
    data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[7]] = np.array(info2.iloc[[12*(int((u+1)/2.)-11)+5*(line-1)+n],[15]])[0][0]
    data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[9]] = np.array(info2.iloc[[12*(int((u+1)/2.)-11)+5*(line-1)+n],[13]])[0][0]
          
    if line == 1: data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[10]] = np.array(info2.iloc[[12*(int((u+1)/2.)-11)+5*(line-1)+n],[8]])[0][0]
    if line == 2: data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[u],np.array(marker['tic-tot'].astype(int))[u+1])],[10]] = np.array(info2.iloc[[12*(int((u+1)/2.)-11)+5*(line-1)+n],[11]])[0][0]

# %%
marker = pd.read_excel('After_Soc/1/Markers_1-2.xls')
marker = marker[np.isfinite(marker['sec'])]
marker
# Out:
#              [Main] Unnamed: 1            3  tic-tot  sec-tot   tic   min  \
# 4     Position=1562         ГЗ   [Marker 1]   1562.0     31.0  12.0   0.0
# 7     Position=3049     ГЗ_end   [Marker 2]   3049.0     60.0  49.0   1.0
# 10    Position=4648          1   [Marker 3]   4648.0     92.0  48.0   1.0
# 13    Position=5657          1   [Marker 4]   5657.0    113.0   7.0   1.0
# 16    Position=6304          2   [Marker 5]   6304.0    126.0   4.0   2.0
# 19    Position=7550          2   [Marker 6]   7550.0    151.0   0.0   2.0
# 22    Position=8182          3   [Marker 7]   8182.0    163.0  32.0   2.0
# 25    Position=9072          3   [Marker 8]   9072.0    181.0  22.0   3.0
# 28    Position=9713          4   [Marker 9]   9713.0    194.0  13.0   3.0
# 31   Position=10608          4  [Marker 10]  10608.0    212.0   8.0   3.0
# 34   Position=10863          5  [Marker 11]  10863.0    217.0  13.0   3.0
# 37   Position=11804          5  [Marker 12]  11804.0    236.0   4.0   3.0
# 40   Position=12237          6  [Marker 13]  12237.0    244.0  37.0   4.0
# 43   Position=13802          6  [Marker 14]  13802.0    276.0   2.0   4.0
# 46   Position=14050          7  [Marker 15]  14050.0    281.0   0.0   4.0
# 49   Position=14626          7  [Marker 16]  14626.0    292.0  26.0   4.0
# 52   Position=15244          8  [Marker 17]  15244.0    304.0  44.0   5.0
# 55   Position=15704          8  [Marker 18]  15704.0    314.0   4.0   5.0
# 58   Position=16719          9  [Marker 19]  16719.0    334.0  19.0   5.0
# 61   Position=17616          9  [Marker 20]  17616.0    352.0  16.0   5.0
# 64   Position=18176         10  [Marker 21]  18176.0    363.0  26.0   6.0
# 67   Position=19329         10  [Marker 22]  19329.0    386.0  29.0   6.0
# 70   Position=19939          1  [Marker 23]  19939.0    398.0  39.0   6.0
# 73   Position=21359          1  [Marker 24]  21359.0    427.0   9.0   7.0
# 76   Position=22185          2  [Marker 25]  22185.0    443.0  35.0   7.0
# 79   Position=23173          2  [Marker 26]  23173.0    463.0  23.0   7.0
# 82   Position=24081          3  [Marker 27]  24081.0    481.0  31.0   8.0
# 85   Position=24807          3  [Marker 28]  24807.0    496.0   7.0   8.0
# 88   Position=25650          4  [Marker 29]  25650.0    513.0   0.0   8.0
# 91   Position=26483          4  [Marker 30]  26483.0    529.0  33.0   8.0
# 94   Position=27405          5  [Marker 31]  27405.0    548.0   5.0   9.0
# 97   Position=28186          5  [Marker 32]  28186.0    563.0  36.0   9.0
# 100  Position=28990          6  [Marker 33]  28990.0    579.0  40.0   9.0
# 103  Position=30271          6  [Marker 34]  30271.0    605.0  21.0  10.0
# 106  Position=31564          7  [Marker 35]  31564.0    631.0  14.0  10.0
# 109  Position=32940          7  [Marker 36]  32940.0    658.0  40.0  10.0
# 112  Position=34864          8  [Marker 37]  34864.0    697.0  14.0  11.0
# 115  Position=36133          8  [Marker 38]  36133.0    722.0  33.0  12.0
# 118  Position=37114          9  [Marker 39]  37114.0    742.0  14.0  12.0
# 121  Position=38316          9  [Marker 40]  38316.0    766.0  16.0  12.0
# 124  Position=39626         10  [Marker 41]  39626.0    792.0  26.0  13.0
# 127  Position=40921         10  [Marker 42]  40921.0    818.0  21.0  13.0
# 130  Position=42790  Contr_end  [Marker 43]  42790.0    855.0  40.0  14.0
#
#       sec         t  Δt, sec
# 4    31.0   0:31.12     31.0
# 7     0.0    1:0.49     29.0
# 10   32.0   1:32.48     32.0
# 13   53.0    1:53.7     21.0
# 16    6.0     2:6.4     13.0
# 19   31.0    2:31.0     25.0
# 22   43.0   2:43.32     12.0
# 25    1.0    3:1.22     18.0
# 28   14.0   3:14.13     13.0
# 31   32.0    3:32.8     18.0
# 34   37.0   3:37.13      5.0
# 37   56.0    3:56.4     19.0
# 40    4.0    4:4.37      8.0
# 43   36.0    4:36.2     32.0
# 46   41.0    4:41.0      5.0
# 49   52.0   4:52.26     11.0
# 52    4.0    5:4.44     12.0
# 55   14.0    5:14.4     10.0
# 58   34.0   5:34.19     20.0
# 61   52.0   5:52.16     18.0
# 64    3.0    6:3.26     11.0
# 67   26.0   6:26.29     23.0
# 70   38.0   6:38.39     12.0
# 73    7.0     7:7.9     29.0
# 76   23.0   7:23.35     16.0
# 79   43.0   7:43.23     20.0
# 82    1.0    8:1.31     18.0
# 85   16.0    8:16.7     15.0
# 88   33.0    8:33.0     17.0
# 91   49.0   8:49.33     16.0
# 94    8.0     9:8.5     19.0
# 97   23.0   9:23.36     15.0
# 100  39.0   9:39.40     16.0
# 103   5.0   10:5.21     26.0
# 106  31.0  10:31.14     26.0
# 109  58.0  10:58.40     27.0
# 112  37.0  11:37.14     39.0
# 115   2.0   12:2.33     25.0
# 118  22.0  12:22.14     20.0
# 121  46.0  12:46.16     24.0
# 124  12.0  13:12.26     26.0
# 127  38.0  13:38.21     26.0
# 130  15.0  14:15.40     37.0
