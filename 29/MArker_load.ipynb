# %%
import pandas as pd
import numpy as np
from pandas import ExcelWriter
from openpyxl import Workbook


names = [u'Беликова Мария',
u'Ракутин Юрий',
u'Анисимов Александр',
u'Полукеева Вера',
u'Плотников Аким',
u'Слижикова Анна',
u'Бальков Андрей',
u'Яновская Елизавета',
u'Дмитриев Егор',
u'Михайлов Владислав']


#folder = '2016-03-11_Collective_action'
state = 'Before_Soc'

wb = Workbook()
wb.save(filename = '{}_INFO.xlsx'.format(state))
for line in [1]:
    for n in range(5,10):
       
            
            
        if (2*n<9): x = pd.read_csv('{}/1/000{}_X'.format(state, 2*n), skiprows=10, sep=')', names = ['time','X'],index_col = False)
        if (2*n<9): y = pd.read_csv('{}/1/000{}_Y'.format(state, 2*n), skiprows=10, sep=')', names = ['time','Y'],index_col = False)
        if (2*n<9): z = pd.read_csv('{}/1/000{}_PZ'.format(state, 2*n+1), skiprows=10, sep=')',names = ['time','Z'],index_col = False)
        
        if (2*n>9): x = pd.read_csv('{}/2/000{}_X'.format(state, 2*(n-5)), skiprows=10, sep=')', names = ['time','X'],index_col = False)
        if (2*n>9): y = pd.read_csv('{}/2/000{}_Y'.format(state, 2*(n-5)), skiprows=10, sep=')', names = ['time','Y'],index_col = False)
        if (2*n>9): z = pd.read_csv('{}/2/000{}_PZ'.format(state, 2*(n-5)+1), skiprows=10, sep=')',names = ['time','Z'],index_col = False)
        
        #info = pd.read_excel('160401_SO1-2.xlsx',sheetname=u'160325_О1', index_col=0)
        #info2 = pd.read_excel('160325_SO1-2.xlsx',sheetname=u'О2', index_col=0)            
        data = x.merge(y).merge(z)
        #data['marker'] = '0'
        data['stad'] = '0'#4
        data['Profit'] = '0'#5
        data['TP'] = '0'#6
        data['LP'] = '0'#7
        data['Sum'] = '0'#8
        data['TH'] = '0'#9
        zt = pd.read_csv('160429_1256.csv',skiprows=32, sep = ';')
        a = list(zt.columns)
        a[0] = 'lol'
        zt.columns = a
        start = float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '1'].iloc[[1],[9]])[0][0])
        start2 = float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[1],[9]])[0][0])
        start3 = float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '1'].iloc[[1],[9]])[0][0])
        start4 = float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '1'].iloc[[1],[9]])[0][0])
        
        
        marker = pd.read_excel('Before_Soc/2/Markers_2-1.xls')
        marker = marker[np.isfinite(marker['sec'])]
        start_extract0 = float(np.array(marker.iloc[[2],[3]])[0][0])
        start_contrib0 = float(np.array(marker.iloc[[6],[3]])[0][0])
        start_extract1 = float(np.array(marker.iloc[[12],[3]])[0][0])
        start_contrib1 = float(np.array(marker.iloc[[17],[3]])[0][0])
        
        

        for u in range(1, 6):
            data.iloc[[j for j in range (int(start_extract0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start)), int(start_extract0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start)))],[4]] = 'Extract per{} start'.format(u)

            data.iloc[[j for j in range (int(start_extract0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start)), int(start_extract0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[5]])[0][0])

            data.iloc[[j for j in range (int(start_extract0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start)), int(start_extract0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start)))],[7]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[19]])[0][0])

            data.iloc[[j for j in range (int(start_extract0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start)), int(start_extract0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[18]])[0][0])


            if float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) == 0:
                data.iloc[[j for j in range (int(start_extract0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 12 - start)))],[4]] = 'Extract per{} res'.format(u)
                data.iloc[[j for j in range (int(start_extract0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 12 - start)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[5]])[0][0])
                data.iloc[[j for j in range (int(start_extract0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 12 - start)))],[7]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[19]])[0][0])
                data.iloc[[j for j in range (int(start_extract0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 12 - start)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[18]])[0][0])

            else:    
                data.iloc[[j for j in range (int(start_extract0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start)))],[4]] = 'Extract per{} res'.format(u)
                data.iloc[[j for j in range (int(start_extract0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[5]])[0][0])
                data.iloc[[j for j in range (int(start_extract0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start)))],[7]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[19]])[0][0])
                data.iloc[[j for j in range (int(start_extract0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start)), int(start_extract0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 3][zt.Period == '{}'.format(u)].iloc[[n],[18]])[0][0])

                
        
        data.iloc[[j for j in range (int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start2)))],[4]] = 'Contrib per{} start'.format(1)

        data.iloc[[j for j in range (int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start2)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[5]])[0][0])

        data.iloc[[j for j in range (int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start2)))],[6]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[50]])[0][0])

        data.iloc[[j for j in range (int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start2)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[48]])[0][0])

        data.iloc[[j for j in range (int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start2)))],[9]] = float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[29]])[0][0])

        data.iloc[[j for j in range (int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start2)))],[9]] += float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '1'].iloc[[n],[32]])[0][0])

        for u in range(2, 6):
            data.iloc[[j for j in range (int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start2)))],[4]] = 'Contrib per{} start'.format(u)

            data.iloc[[j for j in range (int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start2)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[5]])[0][0])

            data.iloc[[j for j in range (int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start2)))],[6]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[50]])[0][0])

            data.iloc[[j for j in range (int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start2)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[48]])[0][0])

            data.iloc[[j for j in range (int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start2)))],[9]] = float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[29]])[0][0])

            data.iloc[[j for j in range (int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start2)), int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start2)))],[9]] += float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[32]])[0][0])



            if float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) == 0:
                data.iloc[[j for j in range (int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 20 - start2)))],[4]] = 'Contrib per{} res'.format(u-1)
                data.iloc[[j for j in range (int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 20 - start2)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[5]])[0][0])
                data.iloc[[j for j in range (int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 20 - start2)))],[6]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[50]])[0][0])
                data.iloc[[j for j in range (int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 20 - start2)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[48]])[0][0])
                data.iloc[[j for j in range (int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 20 - start2)))],[9]] = float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[29]])[0][0])
                data.iloc[[j for j in range (int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 20 - start2)))],[9]] += float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[32]])[0][0])

            else:    
                data.iloc[[j for j in range (int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start2)))],[4]] = 'Contrib per{} res'.format(u-1)
                data.iloc[[j for j in range (int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start2)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[5]])[0][0])
                data.iloc[[j for j in range (int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start2)))],[6]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[50]])[0][0])
                data.iloc[[j for j in range (int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start2)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[48]])[0][0])
                data.iloc[[j for j in range (int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start2)))],[9]] = float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[29]])[0][0])
                data.iloc[[j for j in range (int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start2)), int(start_contrib0 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start2)))],[9]] += float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 4][zt.Period == '{}'.format(u-1)].iloc[[n],[32]])[0][0])

                
                
                
                
       
        for u in range(1, 6):
            data.iloc[[j for j in range (int(start_extract1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start3)), int(start_extract1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start3)))],[4]] = 'Extract per{} start'.format(u)

            data.iloc[[j for j in range (int(start_extract1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start3)), int(start_extract1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start3)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[5]])[0][0])
            data.iloc[[j for j in range (int(start_extract1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start3)), int(start_extract1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start3)))],[7]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[19]])[0][0])

            data.iloc[[j for j in range (int(start_extract1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start3)), int(start_extract1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start3)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[18]])[0][0])


            if float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) == 0:
                data.iloc[[j for j in range (int(start_extract1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start3)), int(start_extract1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 12 - start3)))],[4]] = 'Extract per{} res'.format(u)
                data.iloc[[j for j in range (int(start_extract1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start3)), int(start_extract1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 12 - start3)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[5]])[0][0])
                data.iloc[[j for j in range (int(start_extract1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start3)), int(start_extract1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 12 - start3)))],[7]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[19]])[0][0])
                data.iloc[[j for j in range (int(start_extract1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start3)), int(start_extract1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 12 - start3)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[18]])[0][0])

            else:    
                data.iloc[[j for j in range (int(start_extract1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start3)), int(start_extract1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start3)))],[4]] = 'Extract per{} res'.format(u)
                data.iloc[[j for j in range (int(start_extract1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start3)), int(start_extract1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start3)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[5]])[0][0])
                data.iloc[[j for j in range (int(start_extract1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start3)), int(start_extract1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start3)))],[7]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[19]])[0][0])
                data.iloc[[j for j in range (int(start_extract1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start3)), int(start_extract1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start3)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 5][zt.Period == '{}'.format(u)].iloc[[n],[18]])[0][0])

            
        
        data.iloc[[j for j in range (int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start4)), int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start4)))],[4]] = 'Contrib per{} start'.format(1)

        data.iloc[[j for j in range (int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start4)), int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start4)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '1'].iloc[[n],[5]])[0][0])

        data.iloc[[j for j in range (int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start4)), int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start4)))],[6]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '1'].iloc[[n],[50]])[0][0])

        data.iloc[[j for j in range (int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start4)), int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start4)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '1'].iloc[[n],[48]])[0][0])

        data.iloc[[j for j in range (int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start4)), int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start4)))],[9]] = float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '1'].iloc[[n],[29]])[0][0])

        data.iloc[[j for j in range (int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '1'].iloc[[n],[9]])[0][0]) - start4)), int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '1'].iloc[[n],[10]])[0][0]) - start4)))],[9]] += float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '1'].iloc[[n],[32]])[0][0])

        for u in range(2, 6):
            data.iloc[[j for j in range (int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start4)), int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start4)))],[4]] = 'Contrib per{} start'.format(u)

            data.iloc[[j for j in range (int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start4)), int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start4)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[5]])[0][0])

            data.iloc[[j for j in range (int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start4)), int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start4)))],[6]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[50]])[0][0])

            data.iloc[[j for j in range (int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start4)), int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start4)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[48]])[0][0])

            data.iloc[[j for j in range (int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start4)), int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start4)))],[9]] = float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[29]])[0][0])

            data.iloc[[j for j in range (int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[9]])[0][0]) - start4)), int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[10]])[0][0]) - start4)))],[9]] += float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[32]])[0][0])



            if float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) == 0:
                data.iloc[[j for j in range (int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start4)), int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 20 - start4)))],[4]] = 'Contrib per{} res'.format(u-1)
                data.iloc[[j for j in range (int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start4)), int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 20 - start4)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u-1)].iloc[[n],[5]])[0][0])
                data.iloc[[j for j in range (int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start4)), int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 20 - start4)))],[6]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u-1)].iloc[[n],[50]])[0][0])
                data.iloc[[j for j in range (int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start4)), int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 20 - start4)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u-1)].iloc[[n],[48]])[0][0])
                data.iloc[[j for j in range (int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start4)), int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 20 - start4)))],[9]] = float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u-1)].iloc[[n],[29]])[0][0])
                data.iloc[[j for j in range (int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start4)), int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) + 20 - start4)))],[9]] += float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u-1)].iloc[[n],[32]])[0][0])

            else:    
                data.iloc[[j for j in range (int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start4)), int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start4)))],[4]] = 'Contrib per{} res'.format(u-1)
                data.iloc[[j for j in range (int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start4)), int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start4)))],[5]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u-1)].iloc[[n],[5]])[0][0])
                data.iloc[[j for j in range (int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start4)), int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start4)))],[6]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u-1)].iloc[[n],[50]])[0][0])
                data.iloc[[j for j in range (int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start4)), int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start4)))],[8]] = int(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u-1)].iloc[[n],[48]])[0][0])
                data.iloc[[j for j in range (int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start4)), int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start4)))],[9]] = float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u-1)].iloc[[n],[29]])[0][0])
                data.iloc[[j for j in range (int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[11]])[0][0]) - start4)), int(start_contrib1 + 50*(float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u)].iloc[[n],[12]])[0][0]) - start4)))],[9]] += float(np.array(zt[zt.subjects == 'subjects'][zt.lol == 6][zt.Period == '{}'.format(u-1)].iloc[[n],[32]])[0][0])

 
                
                
                       
                
                
        data.iloc[[j for j in range (0,np.array(marker['tic-tot'].astype(int))[0])],[4]] = u'ГО'
        data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[0],np.array(marker['tic-tot'].astype(int))[1])],[4]] = u'ГЗ'
        
        #data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[20],np.array(marker['tic-tot'].astype(int))[21])],[4]] = u'ГО'
        #data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[21],np.array(marker['tic-tot'].astype(int))[22])],[4]] = u'ГЗ'

        #data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[21],np.array(marker['tic-tot'].astype(int))[22])],[4]] = u'ГО'
        #data.iloc[[j for j in range (np.array(marker['tic-tot'].astype(int))[22],np.array(marker['tic-tot'].astype(int))[23])],[4]] = u'ГЗ'


        
        from openpyxl import load_workbook

        book = load_workbook('{}_INFO.xlsx'.format(state))
        writer = pd.ExcelWriter('{}_INFO.xlsx'.format(state), engine='openpyxl') 
        writer.book = book
        writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

        data.to_excel(writer, sheet_name=str(n+1)+names[n])
        
        writer.save()
# Out:
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:51: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:52: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:53: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:54: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:67: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:69: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:71: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:73: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:76: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:83: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:84: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:85: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:86: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:90: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:92: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:94: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:96: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:98: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:100: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:103: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:105: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:107: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:109: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:111: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:113: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:117: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:126: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:127: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:128: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:129: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:130: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:131: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:118: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:119: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:120: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:121: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:122: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:123: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:139: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:141: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:142: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:144: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:147: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:154: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:155: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:156: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:157: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:161: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:163: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:165: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:167: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:169: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:171: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:174: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:176: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:178: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:180: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:182: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:184: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:188: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:197: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:198: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:199: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:200: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:201: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:202: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:189: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:190: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:191: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:192: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:193: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/antonzaharenkov/Documents/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:194: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
